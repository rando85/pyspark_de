# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

sc = spark.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/03 20:11:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/04/03 20:11:12 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
df = spark.read.parquet('./data/datos.parquet')

# %%
df.show()
# Out:
# +-----------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+-------+------+--------+-------------+--------------------+-----------------+----------------+----------------------+--------------------+
# |   video_id|trending_date|               title|       channel_title|category_id|       publish_time|                tags|  views| likes|dislikes|comment_count|      thumbnail_link|comments_disabled|ratings_disabled|video_error_or_removed|         description|
# +-----------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+-------+------+--------+-------------+--------------------+-----------------+----------------+----------------------+--------------------+
# |2kyS6SvSYSE|     17.14.11|WE WANT TO TALK A...|        CaseyNeistat|         22|2017-11-13 11:13:01|     SHANtell martin| 748374| 57527|    2966|        15954|https://i.ytimg.c...|            False|           False|                 False|SHANTELL'S CHANNE...|
# |1ZAPwfrtAFY|     17.14.11|The Trump Preside...|     LastWeekTonight|         24|2017-11-13 01:30:00|"last week tonigh...|2418783| 97185|    6146|        12703|https://i.ytimg.c...|            False|           False|                 False|One year after th...|
# |5qpjK5DgCt4|     17.14.11|Racist Superman |...|        Rudy Mancuso|         23|2017-11-12 13:05:24|"racist superman"...|3191434|146033|    5339|         8181|https://i.ytimg.c...|            False|           False|                 False|WATCH MY PREVIOUS...|
# |puqaWrEC7tY|     17.14.11|Nickelback Lyrics...|Good Mythical Mor...|         24|2017-11-13 05:00:04|"rhett and link"|...| 343168| 10172|     666|         2146|https://i.ytimg.c...|            False|           False|                 False|Today we find out...|
# |d380meD0W0M|     17.14.11|I Dare You: GOING...|            nigahiga|         24|2017-11-12 12:01:41|"ryan"|"higa"|"hi...|2095731|132235|    1989|        17518|https://i.ytimg.c...|            False|           False|                 False|I know it's been ...|
# |gHZ1Qz0KiKM|     17.14.11|2 Weeks with iPho...|            iJustine|         28|2017-11-13 13:07:23|"ijustine"|"week ...| 119180|  9763|     511|         1434|https://i.ytimg.c...|            False|           False|                 False|Using the iPhone ...|
# |39idVpFF7NQ|     17.14.11|Roy Moore & Jeff ...| Saturday Night Live|         24|2017-11-11 23:37:17|"SNL"|"Saturday N...|2103417| 15993|    2445|         1970|https://i.ytimg.c...|            False|           False|                 False|Embattled Alabama...|
# |nc99ccSXST0|     17.14.11|5 Ice Cream Gadge...|  CrazyRussianHacker|         28|2017-11-12 15:50:37|"5 Ice Cream Gadg...| 817732| 23663|     778|         3432|https://i.ytimg.c...|            False|           False|                 False|Ice Cream Pint Co...|
# |jr9QtXwC9vc|     17.14.11|The Greatest Show...|    20th Century Fox|          1|2017-11-13 08:00:23|"Trailer"|"Hugh J...| 826059|  3543|     119|          340|https://i.ytimg.c...|            False|           False|                 False|Inspired by the i...|
# |TUmyygCMMGA|     17.14.11|Why the rise of t...|                 Vox|         25|2017-11-13 07:45:16|"vox.com"|"vox"|"...| 256426| 12654|    1363|         2368|https://i.ytimg.c...|            False|           False|                 False|For now, at least...|
# |9wRQljFNDW8|     17.14.11|Dion Lewis' 103-Y...|                 NFL|         17|2017-11-12 20:05:26|"NFL"|"Football"|...|  81377|   655|      25|          177|https://i.ytimg.c...|            False|           False|                 False|New England Patri...|
# |VifQlJit6A0|     17.14.11|(SPOILERS) 'Shiva...|                 amc|         24|2017-11-12 21:00:00|"The Walking Dead...| 104578|  1576|     303|         1279|https://i.ytimg.c...|            False|           False|                 False|Shiva arrives jus...|
# |5E4ZBSInqUU|     17.14.11|Marshmello - Bloc...|          marshmello|         10|2017-11-13 11:00:00|"marshmello"|"blo...| 687582|114188|    1333|         8371|https://i.ytimg.c...|            False|           False|                 False|WATCH SILENCE MUS...|
# |GgVmn66oK_A|     17.14.11|Which Countries A...|       NowThis World|         25|2017-11-12 08:00:00|"nowthis"|"nowthi...| 544770|  7848|    1171|         3981|https://i.ytimg.c...|            False|           False|                 False|The world at larg...|
# |TaTleo4cOs8|     17.14.11|SHOPPING FOR NEW ...|     The king of DIY|         15|2017-11-12 12:30:01|"shopping for new...| 207532|  7473|     246|         2120|https://i.ytimg.c...|            False|           False|                 False|Today we go shopp...|
# |kgaO45SyaO4|     17.14.11|    The New SpotMini|      BostonDynamics|         28|2017-11-13 14:09:58|"Robots"|"Boston ...|  75752|  9419|      52|         1230|https://i.ytimg.c...|            False|           False|                 False|For more informat...|
# |ZAQs-ctOqXQ|     17.14.11|One Change That W...|             Cracked|         23|2017-11-12 11:00:05|"pacific rim"|"pa...| 295639|  8011|     638|         1256|https://i.ytimg.c...|            False|           False|                 False|Pacific Rim was s...|
# |YVfyYrEmzgM|     17.14.11|How does your bod...|              TED-Ed|         27|2017-11-13 10:00:07|"TED"|"TED-Ed"|"T...|  78044|  5398|      53|          385|https://i.ytimg.c...|            False|           False|                 False|Check out our Pat...|
# |eNSN6qet1kE|     17.14.11|HomeMade Electric...|         PeterSripol|         28|2017-11-13 09:30:17|"ultralight"|"air...|  97007| 11963|      36|         2211|https://i.ytimg.c...|            False|           False|                 False|aaaannnd now to f...|
# |B5HORANmzHw|     17.14.11|Founding An Inbre...|             SciShow|         27|2017-11-12 16:00:01|"SciShow"|"scienc...| 223871|  8421|     191|         1214|https://i.ytimg.c...|            False|           False|                 False|Thanks to 23AndMe...|
# +-----------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+-------+------+--------+-------------+--------------------+-----------------+----------------+----------------------+--------------------+
# only showing top 20 rows

# %%
df.show(5)
# Out:
# +-----------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+-------+------+--------+-------------+--------------------+-----------------+----------------+----------------------+--------------------+
# |   video_id|trending_date|               title|       channel_title|category_id|       publish_time|                tags|  views| likes|dislikes|comment_count|      thumbnail_link|comments_disabled|ratings_disabled|video_error_or_removed|         description|
# +-----------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+-------+------+--------+-------------+--------------------+-----------------+----------------+----------------------+--------------------+
# |2kyS6SvSYSE|     17.14.11|WE WANT TO TALK A...|        CaseyNeistat|         22|2017-11-13 11:13:01|     SHANtell martin| 748374| 57527|    2966|        15954|https://i.ytimg.c...|            False|           False|                 False|SHANTELL'S CHANNE...|
# |1ZAPwfrtAFY|     17.14.11|The Trump Preside...|     LastWeekTonight|         24|2017-11-13 01:30:00|"last week tonigh...|2418783| 97185|    6146|        12703|https://i.ytimg.c...|            False|           False|                 False|One year after th...|
# |5qpjK5DgCt4|     17.14.11|Racist Superman |...|        Rudy Mancuso|         23|2017-11-12 13:05:24|"racist superman"...|3191434|146033|    5339|         8181|https://i.ytimg.c...|            False|           False|                 False|WATCH MY PREVIOUS...|
# |puqaWrEC7tY|     17.14.11|Nickelback Lyrics...|Good Mythical Mor...|         24|2017-11-13 05:00:04|"rhett and link"|...| 343168| 10172|     666|         2146|https://i.ytimg.c...|            False|           False|                 False|Today we find out...|
# |d380meD0W0M|     17.14.11|I Dare You: GOING...|            nigahiga|         24|2017-11-12 12:01:41|"ryan"|"higa"|"hi...|2095731|132235|    1989|        17518|https://i.ytimg.c...|            False|           False|                 False|I know it's been ...|
# +-----------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+-------+------+--------+-------------+--------------------+-----------------+----------------+----------------------+--------------------+
# only showing top 5 rows

# %%
df.show(5, truncate=False)
# Out:
# +-----------+-------------+--------------------------------------------------------------+---------------------+-----------+-------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+------+--------+-------------+----------------------------------------------+-----------------+----------------+----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |video_id   |trending_date|title                                                         |channel_title        |category_id|publish_time       |tags                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |views  |likes |dislikes|comment_count|thumbnail_link                                |comments_disabled|ratings_disabled|video_error_or_removed|description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# +-----------+-------------+--------------------------------------------------------------+---------------------+-----------+-------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+------+--------+-------------+----------------------------------------------+-----------------+----------------+----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2kyS6SvSYSE|17.14.11     |WE WANT TO TALK ABOUT OUR MARRIAGE                            |CaseyNeistat         |22         |2017-11-13 11:13:01|SHANtell martin                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |748374 |57527 |2966    |15954        |https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg|False            |False           |False                 |SHANTELL'S CHANNEL - https://www.youtube.com/shantellmartin\nCANDICE - https://www.lovebilly.com\n\nfilmed this video in 4k on this -- http://amzn.to/2sTDnRZ\nwith this lens -- http://amzn.to/2rUJOmD\nbig drone - http://tinyurl.com/h4ft3oy\nOTHER GEAR ---  http://amzn.to/2o3GLX5\nSony CAMERA http://amzn.to/2nOBmnv\nOLD CAMERA; http://amzn.to/2o2cQBT\nMAIN LENS; http://amzn.to/2od5gBJ\nBIG SONY CAMERA; http://amzn.to/2nrdJRO\nBIG Canon CAMERA; http://tinyurl.com/jn4q4vz\nBENDY TRIPOD THING; http://tinyurl.com/gw3ylz2\nYOU NEED THIS FOR THE BENDY TRIPOD; http://tinyurl.com/j8mzzua\nWIDE LENS; http://tinyurl.com/jkfcm8t\nMORE EXPENSIVE WIDE LENS; http://tinyurl.com/zrdgtou\nSMALL CAMERA; http://tinyurl.com/hrrzhor\nMICROPHONE; http://tinyurl.com/zefm4jy\nOTHER MICROPHONE; http://tinyurl.com/jxgpj86\nOLD DRONE (cheaper but still great);http://tinyurl.com/zcfmnmd\n\nfollow me; on http://instagram.com/caseyneistat\non https://www.facebook.com/cneistat\non https://twitter.com/CaseyNeistat\n\namazing intro song by https://soundcloud.com/discoteeth\n\nad disclosure.  THIS IS NOT AN AD.  not selling or promoting anything.  but samsung did produce the Shantell Video as a 'GALAXY PROJECT' which is an initiative that enables creators like Shantell and me to make projects we might otherwise not have the opportunity to make.  hope that's clear.  if not ask in the comments and i'll answer any specifics.|
# |1ZAPwfrtAFY|17.14.11     |The Trump Presidency: Last Week Tonight with John Oliver (HBO)|LastWeekTonight      |24         |2017-11-13 01:30:00|"last week tonight trump presidency"|"last week tonight donald trump"|"john oliver trump"|"donald trump"                                                                                                                                                                                                                                                                                                                                                                                       |2418783|97185 |6146    |12703        |https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg|False            |False           |False                 |One year after the presidential election, John Oliver discusses what we've learned so far and enlists our catheter cowboy to teach Donald Trump what he hasn't.\n\nConnect with Last Week Tonight online...\n\nSubscribe to the Last Week Tonight YouTube channel for more almost news as it almost happens: www.youtube.com/user/LastWeekTonight\n\nFind Last Week Tonight on Facebook like your mom would: http://Facebook.com/LastWeekTonight\n\nFollow us on Twitter for news about jokes and jokes about news: http://Twitter.com/LastWeekTonight\n\nVisit our official site for all that other stuff at once: http://www.hbo.com/lastweektonight                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |5qpjK5DgCt4|17.14.11     |Racist Superman | Rudy Mancuso, King Bach & Lele Pons         |Rudy Mancuso         |23         |2017-11-12 13:05:24|"racist superman"|"rudy"|"mancuso"|"king"|"bach"|"racist"|"superman"|"love"|"rudy mancuso poo bear black white official music video"|"iphone x by pineapple"|"lelepons"|"hannahstocking"|"rudymancuso"|"inanna"|"anwar"|"sarkis"|"shots"|"shotsstudios"|"alesso"|"anitta"|"brazil"|"Getting My Driver's License | Lele Pons"                                                                                                                                                                   |3191434|146033|5339    |8181         |https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg|False            |False           |False                 |WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► https://www.youtube.com/channel/UC5jkXpfnBhlDjqh0ir5FsIQ?sub_confirmation=1\n\nTHANKS FOR WATCHING! LIKE & SUBSCRIBE FOR MORE VIDEOS!\n-----------------------------------------------------------\nFIND ME ON: \nInstagram | http://instagram.com/rudymancuso\nTwitter | http://twitter.com/rudymancuso\nFacebook | http://facebook.com/rudymancuso\n\nCAST: \nRudy Mancuso | http://youtube.com/c/rudymancuso\nLele Pons | http://youtube.com/c/lelepons\nKing Bach | https://youtube.com/user/BachelorsPadTv\n\nVideo Effects: \nCaleb Natale | https://instagram.com/calebnatale\n\nPA:\nPaulina Gregory\n\n\nShots Studios Channels:\nAlesso | https://youtube.com/c/alesso\nAnitta | http://youtube.com/c/anitta\nAnwar Jibawi | http://youtube.com/c/anwar\nAwkward Puppets | http://youtube.com/c/awkwardpuppets\nHannah Stocking | http://youtube.com/c/hannahstocking\nInanna Sarkis | http://youtube.com/c/inanna\nLele Pons | http://youtube.com/c/lelepons\nMaejor | http://youtube.com/c/maejor\nMike Tyson | http://youtube.com/c/miketyson \nRudy Mancuso | http://youtube.com/c/rudymancuso\nShots Studios | http://youtube.com/c/shots\n\n#Rudy\n#RudyMancuso                                                                                                                                                                                                                                         |
# |puqaWrEC7tY|17.14.11     |Nickelback Lyrics: Real or Fake?                              |Good Mythical Morning|24         |2017-11-13 05:00:04|"rhett and link"|"gmm"|"good mythical morning"|"rhett and link good mythical morning"|"good mythical morning rhett and link"|"mythical morning"|"Season 12"|"nickelback lyrics"|"nickelback lyrics real or fake"|"nickelback"|"nickelback songs"|"nickelback song"|"rhett link nickelback"|"gmm nickelback"|"lyrics (website category)"|"nickelback (musical group)"|"rock"|"music"|"lyrics"|"chad kroeger"|"canada"|"music (industry)"|"mythical"|"gmm challenge"|"comedy"|"funny"|"challenge"|343168 |10172 |666     |2146         |https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg|False            |False           |False                 |Today we find out if Link is a Nickelback amateur or a secret Nickelback devotee. GMM #1218\nDon't miss an all new Ear Biscuits: https://goo.gl/xeZNQt\nWatch Part 4: https://youtu.be/MhCdiiB8CQg | Watch Part 2: https://youtu.be/7qiOrNao9fg\nWatch today's episode from the start: http://bit.ly/GMM1218\n\nPick up all of the official GMM merch only at https://mythical.store\n\nFollow Rhett & Link: \nInstagram: https://instagram.com/rhettandlink\nFacebook: https://facebook.com/rhettandlink\nTwitter: https://twitter.com/rhettandlink\nTumblr: https://rhettandlink.tumblr.com\nSnapchat: @realrhettlink\nWebsite: https://mythical.co/\n\nCheck Out Our Other Mythical Channels:\nGood Mythical MORE: https://youtube.com/goodmythicalmore\nRhett & Link: https://youtube.com/rhettandlink\nThis Is Mythical: https://youtube.com/thisismythical\nEar Biscuits: https://applepodcasts.com/earbiscuits\n\nWant to send us something? https://mythical.co/contact\nHave you made a Wheel of Mythicality intro video? Submit it here: https://bit.ly/GMMWheelIntro\n\nIntro Animation by Digital Twigs: https://www.digitaltwigs.com\nIntro & Outro Music by Jeff Zeigler & Sarah Schimeneck https://www.jeffzeigler.com\nWheel of Mythicality theme: https://www.royaltyfreemusiclibrary.com/\nAll Supplemental Music fromOpus 1 Music: https://opus1.sourceaudio.com/\nWe use ‘The Mouse’ by Blue Microphones https://www.bluemic.com/mouse/       |
# |d380meD0W0M|17.14.11     |I Dare You: GOING BALD!?                                      |nigahiga             |24         |2017-11-12 12:01:41|"ryan"|"higa"|"higatv"|"nigahiga"|"i dare you"|"idy"|"rhpc"|"dares"|"no truth"|"comments"|"comedy"|"funny"|"stupid"|"fail"                                                                                                                                                                                                                                                                                                                                                                     |2095731|132235|1989    |17518        |https://i.ytimg.com/vi/d380meD0W0M/default.jpg|False            |False           |False                 |I know it's been a while since we did this show, but we're back with what might be the best episode yet!\nLeave your dares in the comment section! \n\nOrder my book how to write good \nhttp://higatv.com/ryan-higas-how-to-write-good-pre-order-links/\n\nJust Launched New Official Store\nhttps://www.gianthugs.com/collections/ryan\n\nHigaTV Channel\nhttp://www.youtube.com/higatv\n\nTwitter\nhttp://www.twitter.com/therealryanhiga\n\nFacebook\nhttp://www.facebook.com/higatv\n\nWebsite\nhttp://www.higatv.com\n\nInstagram\nhttp://www.instagram.com/notryanhiga\n\nSend us mail or whatever you want here!\nPO Box 232355\nLas Vegas, NV 89105                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +-----------+-------------+--------------------------------------------------------------+---------------------+-----------+-------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+------+--------+-------------+----------------------------------------------+-----------------+----------------+----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
df.take(1)
# Out:
# [Row(video_id='2kyS6SvSYSE', trending_date='17.14.11', title='WE WANT TO TALK ABOUT OUR MARRIAGE', channel_title='CaseyNeistat', category_id='22', publish_time=datetime.datetime(2017, 11, 13, 11, 13, 1), tags='SHANtell martin', views=748374, likes=57527, dislikes=2966, comment_count=15954, thumbnail_link='https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg', comments_disabled='False', ratings_disabled='False', video_error_or_removed='False', description="SHANTELL'S CHANNEL - https://www.youtube.com/shantellmartin\\nCANDICE - https://www.lovebilly.com\\n\\nfilmed this video in 4k on this -- http://amzn.to/2sTDnRZ\\nwith this lens -- http://amzn.to/2rUJOmD\\nbig drone - http://tinyurl.com/h4ft3oy\\nOTHER GEAR ---  http://amzn.to/2o3GLX5\\nSony CAMERA http://amzn.to/2nOBmnv\\nOLD CAMERA; http://amzn.to/2o2cQBT\\nMAIN LENS; http://amzn.to/2od5gBJ\\nBIG SONY CAMERA; http://amzn.to/2nrdJRO\\nBIG Canon CAMERA; http://tinyurl.com/jn4q4vz\\nBENDY TRIPOD THING; http://tinyurl.com/gw3ylz2\\nYOU NEED THIS FOR THE BENDY TRIPOD; http://tinyurl.com/j8mzzua\\nWIDE LENS; http://tinyurl.com/jkfcm8t\\nMORE EXPENSIVE WIDE LENS; http://tinyurl.com/zrdgtou\\nSMALL CAMERA; http://tinyurl.com/hrrzhor\\nMICROPHONE; http://tinyurl.com/zefm4jy\\nOTHER MICROPHONE; http://tinyurl.com/jxgpj86\\nOLD DRONE (cheaper but still great);http://tinyurl.com/zcfmnmd\\n\\nfollow me; on http://instagram.com/caseyneistat\\non https://www.facebook.com/cneistat\\non https://twitter.com/CaseyNeistat\\n\\namazing intro song by https://soundcloud.com/discoteeth\\n\\nad disclosure.  THIS IS NOT AN AD.  not selling or promoting anything.  but samsung did produce the Shantell Video as a 'GALAXY PROJECT' which is an initiative that enables creators like Shantell and me to make projects we might otherwise not have the opportunity to make.  hope that's clear.  if not ask in the comments and i'll answer any specifics.")]

# %%
df.head(1)
# Out:
# [Row(video_id='2kyS6SvSYSE', trending_date='17.14.11', title='WE WANT TO TALK ABOUT OUR MARRIAGE', channel_title='CaseyNeistat', category_id='22', publish_time=datetime.datetime(2017, 11, 13, 11, 13, 1), tags='SHANtell martin', views=748374, likes=57527, dislikes=2966, comment_count=15954, thumbnail_link='https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg', comments_disabled='False', ratings_disabled='False', video_error_or_removed='False', description="SHANTELL'S CHANNEL - https://www.youtube.com/shantellmartin\\nCANDICE - https://www.lovebilly.com\\n\\nfilmed this video in 4k on this -- http://amzn.to/2sTDnRZ\\nwith this lens -- http://amzn.to/2rUJOmD\\nbig drone - http://tinyurl.com/h4ft3oy\\nOTHER GEAR ---  http://amzn.to/2o3GLX5\\nSony CAMERA http://amzn.to/2nOBmnv\\nOLD CAMERA; http://amzn.to/2o2cQBT\\nMAIN LENS; http://amzn.to/2od5gBJ\\nBIG SONY CAMERA; http://amzn.to/2nrdJRO\\nBIG Canon CAMERA; http://tinyurl.com/jn4q4vz\\nBENDY TRIPOD THING; http://tinyurl.com/gw3ylz2\\nYOU NEED THIS FOR THE BENDY TRIPOD; http://tinyurl.com/j8mzzua\\nWIDE LENS; http://tinyurl.com/jkfcm8t\\nMORE EXPENSIVE WIDE LENS; http://tinyurl.com/zrdgtou\\nSMALL CAMERA; http://tinyurl.com/hrrzhor\\nMICROPHONE; http://tinyurl.com/zefm4jy\\nOTHER MICROPHONE; http://tinyurl.com/jxgpj86\\nOLD DRONE (cheaper but still great);http://tinyurl.com/zcfmnmd\\n\\nfollow me; on http://instagram.com/caseyneistat\\non https://www.facebook.com/cneistat\\non https://twitter.com/CaseyNeistat\\n\\namazing intro song by https://soundcloud.com/discoteeth\\n\\nad disclosure.  THIS IS NOT AN AD.  not selling or promoting anything.  but samsung did produce the Shantell Video as a 'GALAXY PROJECT' which is an initiative that enables creators like Shantell and me to make projects we might otherwise not have the opportunity to make.  hope that's clear.  if not ask in the comments and i'll answer any specifics.")]

# %%
from pyspark.sql.functions import col

df.select(col('likes')).collect()
# Out:
# [Row(likes=57527),
#  Row(likes=97185),
#  Row(likes=146033),
#  Row(likes=10172),
#  Row(likes=132235),
#  Row(likes=9763),
#  Row(likes=15993),
#  Row(likes=23663),
#  Row(likes=3543),
#  Row(likes=12654),
#  Row(likes=655),
#  Row(likes=1576),
#  Row(likes=114188),
#  Row(likes=7848),
#  Row(likes=7473),
#  Row(likes=9419),
#  Row(likes=8011),
#  Row(likes=5398),
#  Row(likes=11963),
#  Row(likes=8421),
#  Row(likes=9586),
#  Row(likes=3585),
#  Row(likes=11758),
#  Row(likes=1707),
#  Row(likes=4884),
#  Row(likes=8676),
#  Row(likes=4687),
#  Row(likes=9033),
#  Row(likes=156),
#  Row(likes=715),
#  Row(likes=4035),
#  Row(likes=119),
#  Row(likes=787419),
#  Row(likes=3781),
#  Row(likes=1661),
#  Row(likes=2486),
#  Row(likes=7515),
#  Row(likes=1318),
#  Row(likes=38397),
#  Row(likes=6927),
#  Row(likes=5389),
#  Row(likes=308),
#  Row(likes=7),
#  Row(likes=15186),
#  Row(likes=4451),
#  Row(likes=33505),
#  Row(likes=3417),
#  Row(likes=2017),
#  Row(likes=35),
#  Row(likes=45406),
#  Row(likes=99086),
#  Row(likes=205),
#  Row(likes=15397),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=190083),
#  Row(likes=7250),
#  Row(likes=16116),
#  Row(likes=5734),
#  Row(likes=21),
#  Row(likes=89),
#  Row(likes=8209),
#  Row(likes=10237),
#  Row(likes=52),
#  Row(likes=26917),
#  Row(likes=115795),
#  Row(likes=493),
#  Row(likes=8231),
#  Row(likes=115426),
#  Row(likes=120876),
#  Row(likes=203),
#  Row(likes=55681),
#  Row(likes=1634124),
#  Row(likes=2233),
#  Row(likes=2978),
#  Row(likes=1550),
#  Row(likes=18603),
#  Row(likes=2429),
#  Row(likes=1896),
#  Row(likes=37669),
#  Row(likes=15504),
#  Row(likes=355),
#  Row(likes=23296),
#  Row(likes=8133),
#  Row(likes=2323),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=67),
#  Row(likes=3571),
#  Row(likes=6271),
#  Row(likes=16430),
#  Row(likes=439),
#  Row(likes=34839),
#  Row(likes=82320),
#  Row(likes=438),
#  Row(likes=72593),
#  Row(likes=2282),
#  Row(likes=98804),
#  Row(likes=58967),
#  Row(likes=8599),
#  Row(likes=40195),
#  Row(likes=16396),
#  Row(likes=202676),
#  Row(likes=14338),
#  Row(likes=43875),
#  Row(likes=22326),
#  Row(likes=1731),
#  Row(likes=3283),
#  Row(likes=286268),
#  Row(likes=307435),
#  Row(likes=3305),
#  Row(likes=10138),
#  Row(likes=3327),
#  Row(likes=5048),
#  Row(likes=53572),
#  Row(likes=7999),
#  Row(likes=88417),
#  Row(likes=52829),
#  Row(likes=25115),
#  Row(likes=14303),
#  Row(likes=7693),
#  Row(likes=25122),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=4417),
#  Row(likes=5505),
#  Row(likes=15247),
#  Row(likes=11616),
#  Row(likes=9312),
#  Row(likes=9091),
#  Row(likes=84426),
#  Row(likes=935),
#  Row(likes=11198),
#  Row(likes=2926),
#  Row(likes=19323),
#  Row(likes=1365),
#  Row(likes=32648),
#  Row(likes=7683),
#  Row(likes=3652),
#  Row(likes=4364),
#  Row(likes=11736),
#  Row(likes=1345),
#  Row(likes=1354),
#  Row(likes=2163),
#  Row(likes=443),
#  Row(likes=909),
#  Row(likes=4604),
#  Row(likes=35765),
#  Row(likes=7158),
#  Row(likes=1991),
#  Row(likes=5642),
#  Row(likes=9210),
#  Row(likes=15909),
#  Row(likes=242),
#  Row(likes=65854),
#  Row(likes=810895),
#  Row(likes=16106),
#  Row(likes=11985),
#  Row(likes=20159),
#  Row(likes=10175),
#  Row(likes=31892),
#  Row(likes=49),
#  Row(likes=4989),
#  Row(likes=3809),
#  Row(likes=5894),
#  Row(likes=1170),
#  Row(likes=2),
#  Row(likes=5075),
#  Row(likes=3959),
#  Row(likes=22),
#  Row(likes=10844),
#  Row(likes=23338),
#  Row(likes=3454),
#  Row(likes=4250),
#  Row(likes=681),
#  Row(likes=40),
#  Row(likes=569),
#  Row(likes=23634),
#  Row(likes=47793),
#  Row(likes=420),
#  Row(likes=5748),
#  Row(likes=3),
#  Row(likes=2707),
#  Row(likes=258),
#  Row(likes=1666),
#  Row(likes=5723),
#  Row(likes=1211),
#  Row(likes=6243),
#  Row(likes=121),
#  Row(likes=86207),
#  Row(likes=633),
#  Row(likes=998),
#  Row(likes=15130),
#  Row(likes=426),
#  Row(likes=2195),
#  Row(likes=56867),
#  Row(likes=67227),
#  Row(likes=20289),
#  Row(likes=0),
#  Row(likes=4037),
#  Row(likes=147),
#  Row(likes=57),
#  Row(likes=8388),
#  Row(likes=16352),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=5684),
#  Row(likes=29990),
#  Row(likes=14132),
#  Row(likes=4854),
#  Row(likes=63995),
#  Row(likes=28647),
#  Row(likes=87615),
#  Row(likes=3687),
#  Row(likes=58474),
#  Row(likes=60983),
#  Row(likes=35529),
#  Row(likes=56561),
#  Row(likes=25109),
#  Row(likes=5939),
#  Row(likes=580),
#  Row(likes=122347),
#  Row(likes=17130),
#  Row(likes=478),
#  Row(likes=16754),
#  Row(likes=88099),
#  Row(likes=25188),
#  Row(likes=20518),
#  Row(likes=1197),
#  Row(likes=131784),
#  Row(likes=6310),
#  Row(likes=19138),
#  Row(likes=5198),
#  Row(likes=12699),
#  Row(likes=4553),
#  Row(likes=6095),
#  Row(likes=62),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=9805),
#  Row(likes=1145),
#  Row(likes=15301),
#  Row(likes=10410),
#  Row(likes=12229),
#  Row(likes=180284),
#  Row(likes=11131),
#  Row(likes=975),
#  Row(likes=16433),
#  Row(likes=167696),
#  Row(likes=1950),
#  Row(likes=61),
#  Row(likes=75),
#  Row(likes=20721),
#  Row(likes=8177),
#  Row(likes=87),
#  Row(likes=11162),
#  Row(likes=5162),
#  Row(likes=144816),
#  Row(likes=1440),
#  Row(likes=143),
#  Row(likes=136),
#  Row(likes=2279),
#  Row(likes=8996),
#  Row(likes=831),
#  Row(likes=563),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=26813),
#  Row(likes=6310),
#  Row(likes=5715),
#  Row(likes=7129),
#  Row(likes=276),
#  Row(likes=4303),
#  Row(likes=5246),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=16612),
#  Row(likes=19970),
#  Row(likes=17959),
#  Row(likes=10915),
#  Row(likes=11576),
#  Row(likes=83),
#  Row(likes=398),
#  Row(likes=2530),
#  Row(likes=8339),
#  Row(likes=9086),
#  Row(likes=4719),
#  Row(likes=2229),
#  Row(likes=586),
#  Row(likes=126),
#  Row(likes=9211),
#  Row(likes=6587),
#  Row(likes=930),
#  Row(likes=9606),
#  Row(likes=4212),
#  Row(likes=2265),
#  Row(likes=6240),
#  Row(likes=12862),
#  Row(likes=33),
#  Row(likes=1322),
#  Row(likes=5847),
#  Row(likes=23),
#  Row(likes=4566),
#  Row(likes=2425),
#  Row(likes=217),
#  Row(likes=386),
#  Row(likes=9576),
#  Row(likes=4293),
#  Row(likes=305),
#  Row(likes=18),
#  Row(likes=4170),
#  Row(likes=3218),
#  Row(likes=840642),
#  Row(likes=732),
#  Row(likes=296),
#  Row(likes=44513),
#  Row(likes=136),
#  Row(likes=2896),
#  Row(likes=828),
#  Row(likes=15873),
#  Row(likes=37124),
#  Row(likes=11),
#  Row(likes=4548),
#  Row(likes=4657),
#  Row(likes=216319),
#  Row(likes=103407),
#  Row(likes=2133),
#  Row(likes=47),
#  Row(likes=48000),
#  Row(likes=16060),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=250),
#  Row(likes=408618),
#  Row(likes=170),
#  Row(likes=7589),
#  Row(likes=6073),
#  Row(likes=8409),
#  Row(likes=27068),
#  Row(likes=130373),
#  Row(likes=10429),
#  Row(likes=119348),
#  Row(likes=8795),
#  Row(likes=125205),
#  Row(likes=73),
#  Row(likes=58209),
#  Row(likes=487),
#  Row(likes=19783),
#  Row(likes=44007),
#  Row(likes=374),
#  Row(likes=2556),
#  Row(likes=24115),
#  Row(likes=1721383),
#  Row(likes=2540),
#  Row(likes=36365),
#  Row(likes=9052),
#  Row(likes=382),
#  Row(likes=7108),
#  Row(likes=3085),
#  Row(likes=17),
#  Row(likes=102199),
#  Row(likes=2332),
#  Row(likes=453),
#  Row(likes=9321),
#  Row(likes=3128),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=48219),
#  Row(likes=75023),
#  Row(likes=14843),
#  Row(likes=2284),
#  Row(likes=17023),
#  Row(likes=18992),
#  Row(likes=1576),
#  Row(likes=3823),
#  Row(likes=101831),
#  Row(likes=60500),
#  Row(likes=2404),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=212004),
#  Row(likes=26180),
#  Row(likes=5405),
#  Row(likes=55001),
#  Row(likes=10801),
#  Row(likes=314872),
#  Row(likes=45513),
#  Row(likes=9072),
#  Row(likes=96850),
#  Row(likes=4099),
#  Row(likes=29425),
#  Row(likes=53901),
#  Row(likes=3330),
#  Row(likes=5934),
#  Row(likes=9278),
#  Row(likes=5659),
#  Row(likes=88072),
#  Row(likes=11702),
#  Row(likes=14766),
#  Row(likes=1012),
#  Row(likes=12261),
#  Row(likes=2400),
#  Row(likes=15765),
#  Row(likes=1351),
#  Row(likes=1561),
#  Row(likes=7822),
#  Row(likes=19962),
#  Row(likes=3756),
#  Row(likes=12347),
#  Row(likes=36686),
#  Row(likes=12961),
#  Row(likes=4621),
#  Row(likes=7803),
#  Row(likes=4472),
#  Row(likes=211),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=7800),
#  Row(likes=38734),
#  Row(likes=7979),
#  Row(likes=477),
#  Row(likes=10372),
#  Row(likes=151850),
#  Row(likes=24442),
#  Row(likes=57470),
#  Row(likes=141681),
#  Row(likes=20036),
#  Row(likes=17784),
#  Row(likes=31832),
#  Row(likes=8970),
#  Row(likes=24672),
#  Row(likes=93039),
#  Row(likes=12633),
#  Row(likes=29898),
#  Row(likes=37329),
#  Row(likes=13283),
#  Row(likes=142740),
#  Row(likes=114661),
#  Row(likes=6260),
#  Row(likes=2665),
#  Row(likes=21334),
#  Row(likes=9435),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=43974),
#  Row(likes=3802),
#  Row(likes=76806),
#  Row(likes=72727),
#  Row(likes=17286),
#  Row(likes=85208),
#  Row(likes=3557),
#  Row(likes=35595),
#  Row(likes=2207),
#  Row(likes=77531),
#  Row(likes=32186),
#  Row(likes=259),
#  Row(likes=2793),
#  Row(likes=979),
#  Row(likes=7517),
#  Row(likes=660),
#  Row(likes=17929),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=175),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=6932),
#  Row(likes=9576),
#  Row(likes=2325),
#  Row(likes=23472),
#  Row(likes=84),
#  Row(likes=152975),
#  Row(likes=309),
#  Row(likes=28187),
#  Row(likes=7),
#  Row(likes=1546),
#  Row(likes=91111),
#  Row(likes=6305),
#  Row(likes=21642),
#  Row(likes=3835),
#  Row(likes=5930),
#  Row(likes=455),
#  Row(likes=137819),
#  Row(likes=20489),
#  Row(likes=19),
#  Row(likes=6989),
#  Row(likes=11891),
#  Row(likes=1935),
#  Row(likes=93),
#  Row(likes=2349),
#  Row(likes=4369),
#  Row(likes=1741),
#  Row(likes=1350),
#  Row(likes=252),
#  Row(likes=11251),
#  Row(likes=11933),
#  Row(likes=5140),
#  Row(likes=194199),
#  Row(likes=8895),
#  Row(likes=15887),
#  Row(likes=17988),
#  Row(likes=8451),
#  Row(likes=1445),
#  Row(likes=172379),
#  Row(likes=12958),
#  Row(likes=730),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=5447),
#  Row(likes=9381),
#  Row(likes=4064),
#  Row(likes=1699),
#  Row(likes=9045),
#  Row(likes=127),
#  Row(likes=147110),
#  Row(likes=15482),
#  Row(likes=2338),
#  Row(likes=8012),
#  Row(likes=2892),
#  Row(likes=716),
#  Row(likes=4934),
#  Row(likes=54),
#  Row(likes=7049),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=1814),
#  Row(likes=27632),
#  Row(likes=5855),
#  Row(likes=16946),
#  Row(likes=5320),
#  Row(likes=145),
#  Row(likes=17086),
#  Row(likes=1170),
#  Row(likes=21214),
#  Row(likes=18425),
#  Row(likes=2376),
#  Row(likes=8480),
#  Row(likes=19069),
#  Row(likes=130),
#  Row(likes=9459),
#  Row(likes=143),
#  Row(likes=278),
#  Row(likes=318),
#  Row(likes=2323),
#  Row(likes=423),
#  Row(likes=6345),
#  Row(likes=9431),
#  Row(likes=7010),
#  Row(likes=1679),
#  Row(likes=13613),
#  Row(likes=4345),
#  Row(likes=39),
#  Row(likes=2581),
#  Row(likes=6161),
#  Row(likes=23),
#  Row(likes=83),
#  Row(likes=5012),
#  Row(likes=9905),
#  Row(likes=1801),
#  Row(likes=4511),
#  Row(likes=607),
#  Row(likes=225),
#  Row(likes=4355),
#  Row(likes=154),
#  Row(likes=303),
#  Row(likes=46439),
#  Row(likes=869304),
#  Row(likes=18),
#  Row(likes=4),
#  Row(likes=828),
#  Row(likes=2901),
#  Row(likes=4720),
#  Row(likes=37692),
#  Row(likes=6),
#  Row(likes=769),
#  Row(likes=424406),
#  Row(likes=16467),
#  Row(likes=11),
#  Row(likes=10),
#  Row(likes=6369),
#  Row(likes=106243),
#  Row(likes=4735),
#  Row(likes=280),
#  Row(likes=48),
#  Row(likes=48904),
#  Row(likes=254),
#  Row(likes=233172),
#  Row(likes=182),
#  Row(likes=427),
#  Row(likes=7715),
#  Row(likes=20),
#  Row(likes=139054),
#  Row(likes=1988),
#  Row(likes=10497),
#  Row(likes=8926),
#  Row(likes=121285),
#  Row(likes=77),
#  Row(likes=127412),
#  Row(likes=2691),
#  Row(likes=27121),
#  Row(likes=48511),
#  Row(likes=59673),
#  Row(likes=20371),
#  Row(likes=19),
#  Row(likes=2586),
#  Row(likes=519),
#  Row(likes=1788960),
#  Row(likes=24412),
#  Row(likes=9474),
#  Row(likes=3912),
#  Row(likes=2286),
#  Row(likes=7782),
#  Row(likes=111),
#  Row(likes=2412),
#  Row(likes=3124),
#  Row(likes=115781),
#  Row(likes=460),
#  Row(likes=3869),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=17267),
#  Row(likes=9725),
#  Row(likes=15071),
#  Row(likes=75930),
#  Row(likes=57838),
#  Row(likes=1581),
#  Row(likes=379),
#  Row(likes=20085),
#  Row(likes=102726),
#  Row(likes=37129),
#  Row(likes=28119),
#  Row(likes=386),
#  Row(likes=55628),
#  Row(likes=216119),
#  Row(likes=65594),
#  Row(likes=40775),
#  Row(likes=119107),
#  Row(likes=223821),
#  Row(likes=39816),
#  Row(likes=6729),
#  Row(likes=28309),
#  Row(likes=12594),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=135292),
#  Row(likes=88541),
#  Row(likes=281095),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=5666),
#  Row(likes=789750),
#  Row(likes=23207),
#  Row(likes=14355),
#  Row(likes=6593),
#  Row(likes=50946),
#  Row(likes=61075),
#  Row(likes=31301),
#  Row(likes=25840),
#  Row(likes=1326),
#  Row(likes=70960),
#  Row(likes=5474),
#  Row(likes=18816),
#  Row(likes=11492),
#  Row(likes=5155),
#  Row(likes=18022),
#  Row(likes=21013),
#  Row(likes=61484),
#  Row(likes=84669),
#  Row(likes=29135),
#  Row(likes=23939),
#  Row(likes=108),
#  Row(likes=32749),
#  Row(likes=3849),
#  Row(likes=6133),
#  Row(likes=10814),
#  Row(likes=135815),
#  Row(likes=9821),
#  Row(likes=35950),
#  Row(likes=1389),
#  Row(likes=8184),
#  Row(likes=58902),
#  Row(likes=5172),
#  Row(likes=14353),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=5340),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=18708),
#  Row(likes=98182),
#  Row(likes=3657),
#  Row(likes=21523),
#  Row(likes=41976),
#  Row(likes=151277),
#  Row(likes=3871),
#  Row(likes=46900),
#  Row(likes=5188),
#  Row(likes=2750),
#  Row(likes=5023),
#  Row(likes=3539),
#  Row(likes=2001),
#  Row(likes=1026),
#  Row(likes=4468),
#  Row(likes=91834),
#  Row(likes=4208),
#  Row(likes=314),
#  Row(likes=1184),
#  Row(likes=28058),
#  Row(likes=38795),
#  Row(likes=365),
#  Row(likes=111),
#  Row(likes=4237),
#  Row(likes=33595),
#  Row(likes=8122),
#  Row(likes=30255),
#  Row(likes=174),
#  Row(likes=204),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=None),
#  Row(likes=10327),
#  Row(likes=86),
#  Row(likes=370),
#  Row(likes=10),
#  Row(likes=25373),
#  Row(likes=159600),
#  Row(likes=5189),
#  Row(likes=681),
#  Row(likes=4287),
#  Row(likes=29299),
#  Row(likes=2738),
#  Row(likes=7464),
#  Row(likes=6282),
#  Row(likes=1693),
#  Row(likes=92831),
#  Row(likes=22111),
#  Row(likes=921),
#  Row(likes=21174),
#  Row(likes=142006),
#  Row(likes=1623),
#  Row(likes=7229),
#  Row(likes=12694),
#  Row(likes=5906),
#  Row(likes=37),
#  Row(likes=1834),
#  Row(likes=1990),
#  Row(likes=4544),
#  Row(likes=11637),
#  Row(likes=204840),
#  Row(likes=5562),
#  Row(likes=12392),
#  Row(likes=197),
#  Row(likes=10058),
#  Row(likes=10718),
#  Row(likes=16213),
#  Row(likes=18528),
#  Row(likes=14253),
#  Row(likes=206),
#  Row(likes=175762),
#  Row(likes=1572),
#  Row(likes=5591),
#  Row(likes=4288),
#  Row(likes=10079),
#  Row(likes=2023),
#  Row(likes=8593),
#  Row(likes=16242),
#  Row(likes=2366),
#  Row(likes=149105),
#  Row(likes=1932),
#  Row(likes=28677),
#  Row(likes=28200),
#  Row(likes=17313),
#  Row(likes=5954),
#  Row(likes=146),
#  Row(likes=21839),
#  Row(likes=2448),
#  Row(likes=3194),
#  Row(likes=280),
#  Row(likes=8575),
#  Row(likes=18741),
#  Row(likes=1933),
#  Row(likes=6418),
#  Row(likes=5682),
#  Row(likes=9848),
#  Row(likes=1288),
#  Row(likes=58),
#  Row(likes=7193),
#  Row(likes=430),
#  Row(likes=5065),
#  Row(likes=410),
#  Row(likes=92),
#  Row(likes=131),
#  Row(likes=2742),
#  Row(likes=9519),
#  Row(likes=6408),
#  Row(likes=83),
#  Row(likes=5190),
#  Row(likes=13909),
#  Row(likes=10118),
#  Row(likes=3578),
#  Row(likes=4603),
#  Row(likes=4447),
#  Row(likes=243),
#  Row(likes=1941),
#  Row(likes=620),
#  Row(likes=39),
#  Row(likes=230),
#  Row(likes=4455),
#  Row(likes=309),
#  Row(likes=47602),
#  Row(likes=20),
#  Row(likes=891282),
#  Row(likes=4),
#  Row(likes=438470),
#  Row(likes=831),
#  Row(likes=2908),
#  Row(likes=782),
#  Row(likes=292),
#  Row(likes=11),
#  Row(likes=7),
#  Row(likes=4836),
#  Row(likes=38114),
#  Row(likes=10),
#  Row(likes=16805),
#  Row(likes=4782),
#  Row(likes=48),
#  Row(likes=447),
#  Row(likes=261),
#  Row(likes=248909),
#  Row(likes=49509),
#  Row(likes=146732),
#  Row(likes=6466),
#  Row(likes=20),
#  Row(likes=7773),
#  Row(likes=2028),
#  Row(likes=8985),
#  Row(likes=60434),
#  Row(likes=129182),
#  Row(likes=86),
#  Row(likes=8665),
#  Row(likes=52519),
#  Row(likes=76529),
#  Row(likes=20780),
#  Row(likes=2609),
#  Row(likes=22),
#  Row(likes=150015),
#  Row(likes=1002549),
#  Row(likes=94545),
#  Row(likes=16081),
#  Row(likes=89055),
#  Row(likes=61135),
#  ...]
# 25/04/04 00:43:41 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 936690 ms exceeds timeout 120000 ms
# 25/04/04 00:43:41 WARN SparkContext: Killing executors is not supported by current scheduler.
# 25/04/04 00:43:41 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.68.117:54075
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallbacks(Promise.scala:312)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:176)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/04 00:43:41 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.68.117:54075
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallbacks(Promise.scala:312)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:176)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/04 00:43:50 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.68.117:54075
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/04 00:43:50 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.68.117:54075
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/04 00:44:00 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.68.117:54075
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/04 00:44:00 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.68.117:54075
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# ...
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.68.117:54075
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/04 03:12:08 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.68.117:54075
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/04 03:12:08 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.68.117:54075
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/04 03:12:08 ERROR Executor: Exit as unable to send heartbeats to driver more than 60 times
