# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

sc = spark.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/03 20:21:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/04/03 20:21:04 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/04/03 20:21:04 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
df = spark.read.parquet('./data/datos.parquet')

# %%
df1 = df.repartition(2)

# %%
df1.write.format('csv').option('sep', '|').save('./output/csv')

# %%
df1 = df.coalesce(1).write.format('csv').option('sep', '|').save('./output/csv1')

# %%
df.printSchema()
# Out:
# root
#  |-- video_id: string (nullable = true)
#  |-- trending_date: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- category_id: string (nullable = true)
#  |-- publish_time: timestamp (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- views: integer (nullable = true)
#  |-- likes: integer (nullable = true)
#  |-- dislikes: integer (nullable = true)
#  |-- comment_count: integer (nullable = true)
#  |-- thumbnail_link: string (nullable = true)
#  |-- comments_disabled: string (nullable = true)
#  |-- ratings_disabled: string (nullable = true)
#  |-- video_error_or_removed: string (nullable = true)
#  |-- description: string (nullable = true)

# %%
df.select('comments_disabled').distinct().show()
# Out:
# +-----------------+
# |comments_disabled|
# +-----------------+
# |            False|
# |             null|
# | sports and more.|
# |          Wiz Kid|
# |             True|
# |         farfalle|
# +-----------------+

# %%
from pyspark.sql.functions import col

df_limpio = df.filter(col('comments_disabled').isin('True', 'False'))

# %%
df_limpio.write.partitionBy('comments_disabled').parquet('./output/parquet')
# Out:
# 25/04/03 21:03:42 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 928247 ms exceeds timeout 120000 ms
# 25/04/03 21:03:42 WARN SparkContext: Killing executors is not supported by current scheduler.
# 25/04/03 21:03:49 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# ...
